# %% [markdown]
# # Modeling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.utils.multiclass import unique_labels
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 1.3Ghz

# %%
dataset=pd.read_csv("For_1.3Ghz.csv")
dataset
# Out:
#      CPU LOAD  MEMORY USAGE  PAGE FAULT  CPU IDLE TIME  CACHE MISS  \
# 0    0.003018      0.010959    0.058589       0.007931    0.996903
# 1    0.003015      0.010949    0.059421       0.007893    0.996856
# 2    0.003013      0.010939    0.059369       0.007355    0.996866
# 3    0.003010      0.010929    0.060199       0.007073    0.996821
# 4    0.003010      0.010929    0.060199       0.007065    0.996821
# ..        ...           ...         ...            ...         ...
# 387  0.006233      0.009850    0.148900       0.006086    0.980837
# 388  0.006232      0.009848    0.149740       0.006085    0.980668
# 389  0.006231      0.009847    0.150580       0.006084    0.980498
# 390  0.006230      0.009845    0.151419       0.006083    0.980327
# 391  0.006229      0.009843    0.152257       0.006082    0.980156
#
#      TEMPERATURE       LABEL
# 0       0.050600   58.113546
# 1       0.050552   58.617419
# 2       0.050508   58.468332
# 3       0.050461   57.944083
# ...

# %%
#dataset.dtypes

# %%
le = preprocessing.LabelEncoder()

# %%
X=dataset[['CPU LOAD', 'MEMORY USAGE', 'PAGE FAULT', 'CPU IDLE TIME', 'CACHE MISS', 'TEMPERATURE']]
y=dataset['LABEL']

# %%
y=y.astype('int')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#      CPU LOAD  MEMORY USAGE  PAGE FAULT  CPU IDLE TIME  CACHE MISS  \
# 146  0.005948      0.009953    0.111095       0.006150    0.991109
# 171  0.005944      0.009945    0.132857       0.007809    0.987685
# 225  0.006337      0.010014    0.063370       0.006944    0.995437
# 177  0.005933      0.009928    0.137859       0.006963    0.986828
# 143  0.005951      0.009957    0.108511       0.006152    0.991475
# ..        ...           ...         ...            ...         ...
# 341  0.006277      0.009920    0.109850       0.006129    0.987776
# 99   0.006025      0.010938    0.070880       0.007885    0.995862
# 377  0.006254      0.009883    0.140719       0.006115    0.982427
# 165  0.005954      0.010809    0.127834       0.006155    0.988523
# 363  0.006279      0.010766    0.129064       0.006131    0.984552
#
#      TEMPERATURE
# 146     0.072038
# 171     0.081441
# 225     0.070006
# 177     0.083565
# 143     0.070928
# ..           ...
# 341     0.109797
# ...

# %%
y_test
# Out:
# 193    102
# 156     88
# 244     88
# 386    144
# 129     76
#       ...
# 322    118
# 256     93
# 104     66
# 168     93
# 274    100
# Name: LABEL, Length: 79, dtype: int64

# %%
y_train
# Out:
# 146     83
# 171     93
# 225     79
# 177     96
# 143     82
#       ...
# 341    128
# 99      62
# 377    140
# 165     91
# 363    135
# Name: LABEL, Length: 313, dtype: int64

# %%
sc=StandardScaler()

# %%
scaler = sc.fit(X_train)

# %%
x_train_scaled = scaler.transform(X_train)

# %%
x_test_scaled = scaler.transform(X_test)

# %%
#clf = MLPClassifier(random_state=0, max_iter=100).fit(x_train_scaled, y_train)

# %%
#clf = MLPClassifier(hidden_layer_sizes=(4,4),
                  # random_state=5,
                  # verbose=True,
                   # activation = 'relu',
                    #solver = 'sgd',
                    #learning_rate_init=0.01)
clf = MLPClassifier(solver='sgd',verbose=True,
                    activation = 'relu',
                    hidden_layer_sizes=(4,4), 
                    random_state=1)

# %%
clf.fit(x_train_scaled,y_train)
# Out:
# Iteration 1, loss = 4.49183102
# Iteration 2, loss = 4.49167714
# Iteration 3, loss = 4.49143511
# Iteration 4, loss = 4.49112243
# Iteration 5, loss = 4.49077109
# Iteration 6, loss = 4.49035077
# Iteration 7, loss = 4.48989943
# Iteration 8, loss = 4.48942869
# Iteration 9, loss = 4.48893230
# Iteration 10, loss = 4.48843463
# Iteration 11, loss = 4.48787583
# Iteration 12, loss = 4.48733379
# Iteration 13, loss = 4.48679835
# Iteration 14, loss = 4.48624859
# Iteration 15, loss = 4.48566225
# Iteration 16, loss = 4.48511375
# Iteration 17, loss = 4.48452914
# Iteration 18, loss = 4.48397399
# Iteration 19, loss = 4.48336959
# Iteration 20, loss = 4.48282680
# Iteration 21, loss = 4.48224106
# Iteration 22, loss = 4.48166412
# Iteration 23, loss = 4.48108192
# Iteration 24, loss = 4.48049456
# Iteration 25, loss = 4.47993917
# Iteration 26, loss = 4.47934590
# Iteration 27, loss = 4.47876442
# Iteration 28, loss = 4.47819344
# Iteration 29, loss = 4.47762354
# ...

# %%
y_pred=clf.predict(x_test_scaled)
y_pred
# Out:
# array([114, 114,  62,  61,  61,  61,  61,  61,  61,  61,  61,  61,  61,
#         61,  61,  61,  61,  61,  61,  61,  61,  61,  61,  61,  61,  61,
#         61,  61,  61,  61,  61,  61,  61,  61, 114,  61,  61,  61,  61,
#        123,  61,  61,  61,  61,  61,  61,  61,  62,  61,  61,  61,  61,
#         61,  61,  61,  61, 123,  61, 123,  61,  61,  61,  61,  61,  61,
#         61,  61,  61,  61,  61,  61,  61,  61,  62,  61, 123,  61,  61,
#         61])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.06329113924050633

# %% [markdown]
# # 2Ghz

# %%
dataset1=pd.read_csv("For_2Ghz.csv")
dataset1
# Out:
#      CPU LOAD  MEMORY USAGE  PAGE FAULT  CPU IDLE TIME  CACHE MISS  \
# 0    0.003018      0.010959    0.058589       0.007931    0.996903
# 1    0.003015      0.010949    0.059421       0.007893    0.996856
# 2    0.003013      0.010939    0.059369       0.007355    0.996866
# 3    0.003010      0.010929    0.060199       0.007073    0.996821
# 4    0.003010      0.010929    0.060199       0.007065    0.996821
# ..        ...           ...         ...            ...         ...
# 387  0.006233      0.009850    0.148900       0.006086    0.980837
# 388  0.006232      0.009848    0.149740       0.006085    0.980668
# 389  0.006231      0.009847    0.150580       0.006084    0.980498
# 390  0.006230      0.009845    0.151419       0.006083    0.980327
# 391  0.006229      0.009843    0.152257       0.006082    0.980156
#
#      TEMPERATURE       LABEL
# 0       0.050600   58.113546
# 1       0.050552   58.617419
# 2       0.050508   58.468332
# 3       0.050461   57.944083
# ...

# %%
dataset1.dtypes
# Out:
# CPU LOAD         float64
# MEMORY USAGE     float64
# PAGE FAULT       float64
# CPU IDLE TIME    float64
# CACHE MISS       float64
# TEMPERATURE      float64
# LABEL            float64
# dtype: object

# %%
le = preprocessing.LabelEncoder()

# %%
X=dataset1[['CPU LOAD', 'MEMORY USAGE', 'PAGE FAULT', 'CPU IDLE TIME', 'CACHE MISS', 'TEMPERATURE']]
y=dataset1['LABEL']

# %%
y=y.astype('int')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#      CPU LOAD  MEMORY USAGE  PAGE FAULT  CPU IDLE TIME  CACHE MISS  \
# 340  0.006278      0.009921    0.108993       0.006130    0.987908
# 221  0.006345      0.010027    0.058164       0.007843    0.995840
# 15   0.003004      0.010907    0.062731       0.006211    0.996630
# 381  0.006245      0.009868    0.143975       0.006123    0.981805
# 56   0.005308      0.010921    0.068121       0.006219    0.996160
# ..        ...           ...         ...            ...         ...
# 18   0.003001      0.010898    0.062675       0.006206    0.996623
# 234  0.006330      0.010003    0.064176       0.006207    0.995169
# 288  0.006312      0.009975    0.068385       0.006163    0.993335
# 337  0.006280      0.009925    0.106419       0.006132    0.988300
# 83   0.005285      0.010022    0.067822       0.006201    0.996189
#
#      TEMPERATURE
# 340     0.109463
# 221     0.068687
# 15      0.051245
# 381     0.123107
# 56      0.053278
# ..           ...
# 18      0.051464
# ...

# %%
clf = MLPClassifier(hidden_layer_sizes=(4,4),
                    random_state=0,
                    verbose=True,
                    activation = 'relu',
                    solver = 'sgd',
                    learning_rate_init=0.01)

# %%
clf.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 4.49014083
# Iteration 2, loss = 4.48933779
# Iteration 3, loss = 4.48813158
# Iteration 4, loss = 4.48650513
# Iteration 5, loss = 4.48460513
# Iteration 6, loss = 4.48257760
# Iteration 7, loss = 4.48017802
# Iteration 8, loss = 4.47766788
# Iteration 9, loss = 4.47505814
# Iteration 10, loss = 4.47248740
# Iteration 11, loss = 4.46965683
# Iteration 12, loss = 4.46676162
# Iteration 13, loss = 4.46393946
# Iteration 14, loss = 4.46095338
# Iteration 15, loss = 4.45804918
# Iteration 16, loss = 4.45504597
# Iteration 17, loss = 4.45219442
# Iteration 18, loss = 4.44924440
# Iteration 19, loss = 4.44626912
# Iteration 20, loss = 4.44331401
# Iteration 21, loss = 4.44021960
# Iteration 22, loss = 4.43738765
# Iteration 23, loss = 4.43432841
# Iteration 24, loss = 4.43141363
# Iteration 25, loss = 4.42852781
# Iteration 26, loss = 4.42563724
# Iteration 27, loss = 4.42255735
# Iteration 28, loss = 4.41949692
# Iteration 29, loss = 4.41664870
# ...

# %%
y_pred=clf.predict(X_test)
y_pred
# Out:
# array([61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61,
#        61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61,
#        61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61,
#        61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61,
#        61, 61, 61, 61, 61, 61, 61, 61, 61, 61, 61])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 8.860759493670886e-02
