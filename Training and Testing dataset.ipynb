# %% [markdown]
# # Training and Testing

# %%
import numpy as np

# %%
import matplotlib.pyplot as plot

# %%
import pandas as pd

# %%
from pandas import read_csv

# %%
from sklearn import preprocessing

# %%
import sys
import sklearn
print(sys.version)
# !python --version
print("numpy:",np.__version__)
print("sklearn:",sklearn.__version__)
# Out:
# 3.9.12 (main, Apr  5 2022, 06:56:58)
# [GCC 7.5.0]
# Python 3.9.12
# numpy: 1.21.5
# sklearn: 1.0.2

# %%
dataset=pd.read_csv("For_1.3Ghz.csv")
dataset1=pd.read_csv("For_2Ghz.csv")

# %%
#dataset.drop('Unnamed: 0', inplace=True, axis=1)
dataset = dataset.rename(columns={'0': 'CPU LOAD','1': 'MEMORY USAGE','2': 'PAGE FAULT','3': 'CPU IDLE TIME',
                                  '4': 'CACHE MISS','5': 'TEMPERATURE','y': 'LABEL'})
dataset.to_csv("For_1.3Ghz.csv",index=False)

# %%
dataset
# Out:
#      CPU LOAD  MEMORY USAGE  PAGE FAULT  CPU IDLE TIME  CACHE MISS  \
# 0    0.003018      0.010959    0.058589       0.007931    0.996903
# 1    0.003015      0.010949    0.059421       0.007893    0.996856
# 2    0.003013      0.010939    0.059369       0.007355    0.996866
# 3    0.003010      0.010929    0.060199       0.007073    0.996821
# 4    0.003010      0.010929    0.060199       0.007065    0.996821
# ..        ...           ...         ...            ...         ...
# 387  0.006233      0.009850    0.148900       0.006086    0.980837
# 388  0.006232      0.009848    0.149740       0.006085    0.980668
# 389  0.006231      0.009847    0.150580       0.006084    0.980498
# 390  0.006230      0.009845    0.151419       0.006083    0.980327
# 391  0.006229      0.009843    0.152257       0.006082    0.980156
#
#      TEMPERATURE       LABEL
# 0       0.050600   58.113546
# 1       0.050552   58.617419
# 2       0.050508   58.468332
# 3       0.050461   57.944083
# ...

# %%
#dataset1.drop('Unnamed: 0', inplace=True, axis=1)
dataset1 = dataset1.rename(columns={'0': 'CPU LOAD','1': 'MEMORY USAGE','2': 'PAGE FAULT','3': 'CPU IDLE TIME',
                                  '4': 'CACHE MISS','5': 'TEMPERATURE'})
dataset1.to_csv("For_2Ghz.csv",index=False)
dataset1
# Out:
#      CPU LOAD  MEMORY USAGE  PAGE FAULT  CPU IDLE TIME  CACHE MISS  \
# 0    0.003018      0.010959    0.058589       0.007931    0.996903
# 1    0.003015      0.010949    0.059421       0.007893    0.996856
# 2    0.003013      0.010939    0.059369       0.007355    0.996866
# 3    0.003010      0.010929    0.060199       0.007073    0.996821
# 4    0.003010      0.010929    0.060199       0.007065    0.996821
# ..        ...           ...         ...            ...         ...
# 387  0.006233      0.009850    0.148900       0.006086    0.980837
# 388  0.006232      0.009848    0.149740       0.006085    0.980668
# 389  0.006231      0.009847    0.150580       0.006084    0.980498
# 390  0.006230      0.009845    0.151419       0.006083    0.980327
# 391  0.006229      0.009843    0.152257       0.006082    0.980156
#
#      TEMPERATURE       LABEL
# 0       0.050600   58.113546
# 1       0.050552   58.617419
# 2       0.050508   58.468332
# 3       0.050461   57.944083
# ...

# %%
plot.scatter(dataset['MEMORY USAGE'],dataset['CPU IDLE TIME'])

# %%
X=dataset.iloc[:,0:6]
y=dataset.iloc[:,6:7]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
print ("Train data shape:", dataset.shape)
print ("Test data shape:", dataset.shape)
# Out:
# Train data shape: (392, 7)
# Test data shape: (392, 7)

# %%
X_train
# Out:
#      CPU LOAD  MEMORY USAGE  PAGE FAULT  CPU IDLE TIME  CACHE MISS  \
# 324  0.006302      0.009958    0.095398       0.006984    0.989868
# 365  0.006277      0.010762    0.130768       0.006129    0.984248
# 53   0.005308      0.010921    0.068121       0.007060    0.996156
# 95   0.005275      0.010004    0.068578       0.006181    0.996136
# 244  0.006321      0.009990    0.066726       0.006172    0.994744
# ..        ...           ...         ...            ...         ...
# 51   0.005313      0.010931    0.068181       0.007349    0.996148
# 35   0.005198      0.010025    0.064317       0.006194    0.996468
# 15   0.003004      0.010907    0.062731       0.006211    0.996630
# 45   0.005188      0.010006    0.065954       0.006182    0.996338
# 363  0.006279      0.010766    0.129064       0.006131    0.984552
#
#      TEMPERATURE
# 324     0.104273
# 365     0.118162
# 53      0.053248
# 95      0.053325
# 244     0.076507
# ..           ...
# 51      0.053276
# ...

# %%
y_train
# Out:
#           LABEL
# 324  120.755186
# 365  137.767773
# 53    62.137069
# 95    61.615482
# 244   88.645930
# ..          ...
# 51    61.760154
# 35    61.174105
# 15    59.775508
# 45    60.930058
# 363  135.542976
#
# [313 rows x 1 columns]

# %%
dataset.to_csv("Train and test For_1.3Ghz.csv",index=False)

# %%
x=dataset1.iloc[:,0:6]
Y=dataset1.iloc[:,6:7]

# %%
x
# Out:
#      CPU LOAD  MEMORY USAGE  PAGE FAULT  CPU IDLE TIME  CACHE MISS  \
# 0    0.003018      0.010959    0.058589       0.007931    0.996903
# 1    0.003015      0.010949    0.059421       0.007893    0.996856
# 2    0.003013      0.010939    0.059369       0.007355    0.996866
# 3    0.003010      0.010929    0.060199       0.007073    0.996821
# 4    0.003010      0.010929    0.060199       0.007065    0.996821
# ..        ...           ...         ...            ...         ...
# 387  0.006233      0.009850    0.148900       0.006086    0.980837
# 388  0.006232      0.009848    0.149740       0.006085    0.980668
# 389  0.006231      0.009847    0.150580       0.006084    0.980498
# 390  0.006230      0.009845    0.151419       0.006083    0.980327
# 391  0.006229      0.009843    0.152257       0.006082    0.980156
#
#      TEMPERATURE
# 0       0.050600
# 1       0.050552
# 2       0.050508
# 3       0.050461
# 4       0.050461
# ..           ...
# 387     0.124955
# ...

# %%
x_train, x_test, Y_train, Y_test = train_test_split(x,Y,test_size=0.2)

# %%
x_train
# Out:
#      CPU LOAD  MEMORY USAGE  PAGE FAULT  CPU IDLE TIME  CACHE MISS  \
# 90   0.005280      0.010012    0.068638       0.006186    0.996132
# 171  0.005944      0.009945    0.132857       0.007809    0.987685
# 76   0.005289      0.010031    0.067881       0.007044    0.996180
# 331  0.006291      0.009941    0.101350       0.006160    0.989040
# 16   0.003004      0.010907    0.062731       0.006220    0.996630
# ..        ...           ...         ...            ...         ...
# 13   0.003007      0.010918    0.061908       0.006235    0.996724
# 169  0.005950      0.010803    0.131261       0.006152    0.987955
# 14   0.003004      0.010908    0.061850       0.006238    0.996667
# 217  0.006350      0.010887    0.062615       0.006209    0.995665
# 46   0.005188      0.010005    0.066829       0.006182    0.996280
#
#      TEMPERATURE
# 90      0.053323
# 171     0.081441
# 76      0.053284
# 331     0.106540
# 16      0.051245
# ..           ...
# 13      0.050411
# ...

# %%
Y_train
# Out:
#           LABEL
# 90    62.506554
# 171   93.520927
# 76    61.153422
# 331  123.813272
# 16    58.115849
# ..          ...
# 13    57.100470
# 169   94.346752
# 14    59.014919
# 217   76.925526
# 46    61.233586
#
# [313 rows x 1 columns]

# %%
dataset1.to_csv("Train and test _For_2Ghz.csv",index=False)
